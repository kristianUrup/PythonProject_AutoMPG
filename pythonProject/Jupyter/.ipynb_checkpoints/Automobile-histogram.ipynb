# %%
import pandas as pd
import DataStore as DStore
import DataService as DService

pd.set_option("display.max_rows", None, "display.max_columns", None)
data = pd.read_fwf(DStore.AUTOMOBILE_FILEPATH, header=None,
            names=["mpg","cylinders", "displacement",
                   "horsepower", "weight", "acceleration",
                   "model_year", "origin", "car_name"],
                   na_values='?') # Sets the data to NaN, where the data is '?'
data_by_index = data.reset_index()
train_set, test_set = DService.split_train_test_by_id(data_by_index, 0.2, "index")
print("THE TRAIN SET")
df = pd.DataFrame(train_set)
# Out:
# THE TRAIN SET

# %%
data.hist(bins=20, figsize=(20,15))
# Out:
# array([[<AxesSubplot:title={'center':'mpg'}>,
#         <AxesSubplot:title={'center':'cylinders'}>,
#         <AxesSubplot:title={'center':'displacement'}>],
#        [<AxesSubplot:title={'center':'horsepower'}>,
#         <AxesSubplot:title={'center':'weight'}>,
#         <AxesSubplot:title={'center':'acceleration'}>],
#        [<AxesSubplot:title={'center':'model_year'}>,
#         <AxesSubplot:title={'center':'origin'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
data_changed = df.dropna()
data_changed_reset = data_changed.reset_index()

pd.DataFrame(data_changed_reset)
# Out:
#      level_0  index   mpg  cylinders  displacement  horsepower  weight  \
# 0          0      0  18.0          8         307.0       130.0  3504.0
# 1          1      1  15.0          8         350.0       165.0  3693.0
# 2          2      2  18.0          8         318.0       150.0  3436.0
# 3          3      3  16.0          8         304.0       150.0  3433.0
# 4          6      6  14.0          8         454.0       220.0  4354.0
# 5          7      7  14.0          8         440.0       215.0  4312.0
# 6          8      8  14.0          8         455.0       225.0  4425.0
# 7          9      9  15.0          8         390.0       190.0  3850.0
# 8         10     10  15.0          8         383.0       170.0  3563.0
# 9         12     12  15.0          8         400.0       150.0  3761.0
# 10        13     13  14.0          8         455.0       225.0  3086.0
# 11        14     14  24.0          4         113.0        95.0  2372.0
# ...
